# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in d:\python\venv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in d:\python\venv\lib\site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\python\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\python\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\python\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\python\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# %%
df=pd.read_csv(r'D:\ML\Used_Car_Dataset - Used_Car_Dataset.csv')

# %%
df.head()
# Out:
#    Year  Mileage_km  Engine_Size_cc  Num_Owners  Fuel_Efficiency_kmpl  \
# 0  2014      127989            3062           3             16.249345
# 1  2017      281393            4029           2             17.237899
# 2  2001      249255            2916           3             13.180936
# 3  2009      115361            1192           4             11.090744
# 4  2022      291744            1908           4              9.460477
#
#       Price_INR
# 0  1.636551e+06
# 1  2.206040e+06
# 2  2.615662e+05
# 3  1.660000e+05
# 4  1.660000e+05

# %%
x=df[['Mileage_km']]
y=df[['Price_INR']]

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in d:\python\venv\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in d:\python\venv\lib\site-packages (from scikit-learn) (2.2.4)
# Requirement already satisfied: scipy>=1.6.0 in d:\python\venv\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in d:\python\venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\python\venv\lib\site-packages (from scikit-learn) (3.6.0)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LinearRegression
clf=LinearRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
LinearRegression()
# Out:
# LinearRegression()

# %%
clf.score(x_test,y_test)
# Out:
# 0.07797223010540133

# %%
y_pred=clf.predict(x_test)

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in d:\python\venv\lib\site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\python\venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in d:\python\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\python\venv\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\python\venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in d:\python\venv\lib\site-packages (from matplotlib) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in d:\python\venv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in d:\python\venv\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\python\venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\python\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in d:\python\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))
plt.scatter(x_test,y_test,color='blue',label='Actual Data')
plt.plot(x_test,y_pred,color='red',linewidth=2,label='Regression Line')

plt.xlabel('Mileage_km')
plt.ylabel('Price_INR')
plt.title('Linear Regression with Matplotlib')
plt.legend()
plt.grid(True)
plt.show()
